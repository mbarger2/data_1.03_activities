# %%
#Data 1.03 Activities

# %%
import pandas as pd

# %%
pip install numpy

# %%
import numpy as np

# %%
file1 = pd.read_excel('C:/Users/Matthew/DAclass/1.03/data_1.03_activities/files_for_activities/file3.xlsx')

# %%
file2 = pd.read_excel('C:/Users/Matthew/DAclass/1.03/data_1.03_activities/files_for_activities/file4.xlsx')

# %%
file1.columns==file2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
tfile =pd.concat([file1,file2],axis=0)

# %%
tfile
# Out:
#       controln      state gender   hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 2001     41537         FL      F   742  396  470     0  15356      7     37
# 2002      4881         FL      M   599  100  423     4  11670     10     27
# 2003     66358         ND      M   593  258  299     0  10186      1     70
# 2004      2231         WI   male   564  217  397     0  12315      0     96
# 2005     68534         MI      M   651  431  505     0  14845      7     77
#
#       ic2  ic3    avggift  tcode   dob domain  target_d
# ...

# %%
file1
# Out:
#      CONTROLN      STATE  GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0      119966         TX       F   321  225  281     0   9372      3     68
# 1      152470         CA       F  5725  610  807    97  53158     13     22
# 2       48527         AL    Male   931  407  496     0  17743      0     65
# 3      171528         CA       F  1895  317  471    46  17431     10     62
# 4       50122  Tennessee       F   715  318  370     2  12416      0     75
# ..        ...        ...     ...   ...  ...  ...   ...    ...    ...    ...
# 995    179863         WA    male  1253  325  447     7  15635     12     57
# 996     87395         MT  female   842  264  388     3  15084      2     50
# 997     86779         ND       F   331  165  266     0   9324      1     61
# 998     25214         NC  female  1823  544  567    43  21265      1     62
# 999     79641         WI       F  1244  672  776    25  25036      1     64
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
file2
# Out:
#       CONTROLN STATE GENDER      HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0       186307    CA      M  AAA1229  345  438     3  15915      2     58
# 1        34174    WV      F      529  198  291     0  10816      0     80
# 2       101388    MO      M      526  340  342     0   9687      0     89
# 3       159472    CA      F      621  231  279     0   6184     43     41
# 4       179143    WA   male     1688  496  564    35  22963      2     63
# ...        ...   ...    ...      ...  ...  ...   ...    ...    ...    ...
# 1001     41537    FL      F      742  396  470     0  15356      7     37
# 1002      4881    FL      M      599  100  423     4  11670     10     27
# 1003     66358    ND      M      593  258  299     0  10186      1     70
# 1004      2231    WI   male      564  217  397     0  12315      0     96
# 1005     68534    MI      M      651  431  505     0  14845      7     77
#
#       IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
tfile = tfile.reset_index(drop=True)

# %%
#file.drop(['index'],axis=1,inplace=True)

# %%
tfile
# Out:
#       CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 2001     41537         FL      F   742  396  470     0  15356      7     37
# 2002      4881         FL      M   599  100  423     4  11670     10     27
# 2003     66358         ND      M   593  258  299     0  10186      1     70
# 2004      2231         WI   male   564  217  397     0  12315      0     96
# 2005     68534         MI      M   651  431  505     0  14845      7     77
#
#       IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
low_columns = []
for item in tfile.columns:
    low_columns.append(item.lower())

# %%
low_columns
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d']

# %%
tfile.columns = low_columns

# %%
tfile
# Out:
#       controln      state gender   hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 2001     41537         FL      F   742  396  470     0  15356      7     37
# 2002      4881         FL      M   599  100  423     4  11670     10     27
# 2003     66358         ND      M   593  258  299     0  10186      1     70
# 2004      2231         WI   male   564  217  397     0  12315      0     96
# 2005     68534         MI      M   651  431  505     0  14845      7     77
#
#       ic2  ic3    avggift  tcode   dob domain  target_d
# ...

# %%
data = pd.read_csv('C:/Users/Matthew/DAclass/Class 3/file1.csv')
data2 = pd.read_csv('C:/Users/Matthew/DAclass/Class 3/file2.txt', sep = '\t')
data3 = pd.read_excel('C:/Users/Matthew/DAclass/Class 3/file3.xlsx')
data4 = pd.read_excel('C:/Users/Matthew/DAclass/Class 3/file4.xlsx')

# %%
data
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
data2
# Out:
#       CONTROLN STATE   GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0       190579    CA        M  3200  310  343    83  17224     31     32  311
# 1        42997    FL        F  1567  392  409    27  18631      4     10  391
# 2       132896    OR        F   953  319  455     1  15729      3     45  379
# 3       120189    TX        M   492  244  301     3  10818      0     92  260
# 4       138829    AZ  feamale   847  185  308     0  11582      3     20  238
# ...        ...   ...      ...   ...  ...  ...   ...    ...    ...    ...  ...
# 1010    161838    CA        F  1953  304  380    47  13811     25     43  353
# 1011    161838    CA        F  1953  304  380    47  13811     25     43  353
# 1012    138311    AZ   Female  1708  437  684    36  29098      7     19  586
# 1013    123469    TX        M   561  493  540     1  16623      5     68  529
# 1014    135341    AZ   Female   700  205  295     0  12713      9     12  221
#
# ...

# %%
data3
# Out:
#      CONTROLN      STATE  GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0      119966         TX       F   321  225  281     0   9372      3     68
# 1      152470         CA       F  5725  610  807    97  53158     13     22
# 2       48527         AL    Male   931  407  496     0  17743      0     65
# 3      171528         CA       F  1895  317  471    46  17431     10     62
# 4       50122  Tennessee       F   715  318  370     2  12416      0     75
# ..        ...        ...     ...   ...  ...  ...   ...    ...    ...    ...
# 995    179863         WA    male  1253  325  447     7  15635     12     57
# 996     87395         MT  female   842  264  388     3  15084      2     50
# 997     86779         ND       F   331  165  266     0   9324      1     61
# 998     25214         NC  female  1823  544  567    43  21265      1     62
# 999     79641         WI       F  1244  672  776    25  25036      1     64
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
data4
# Out:
#       CONTROLN STATE GENDER      HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0       186307    CA      M  AAA1229  345  438     3  15915      2     58
# 1        34174    WV      F      529  198  291     0  10816      0     80
# 2       101388    MO      M      526  340  342     0   9687      0     89
# 3       159472    CA      F      621  231  279     0   6184     43     41
# 4       179143    WA   male     1688  496  564    35  22963      2     63
# ...        ...   ...    ...      ...  ...  ...   ...    ...    ...    ...
# 1001     41537    FL      F      742  396  470     0  15356      7     37
# 1002      4881    FL      M      599  100  423     4  11670     10     27
# 1003     66358    ND      M      593  258  299     0  10186      1     70
# 1004      2231    WI   male      564  217  397     0  12315      0     96
# 1005     68534    MI      M      651  431  505     0  14845      7     77
#
#       IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
tdata = pd.concat([data,data2,data3,data4],axis = 0)

# %%
tdata.columns == tfile.columns
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
tdata
# Out:
#       controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 4023     41537    FL      F      742  396  470.0     0  15356      7     37
# 4024      4881    FL      M      599  100  423.0     4  11670     10     27
# 4025     66358    ND      M      593  258  299.0     0  10186      1     70
# 4026      2231    WI   male      564  217  397.0     0  12315      0     96
# 4027     68534    MI      M      651  431  505.0     0  14845      7     77
#
# ...

# %%
tdata = tdata.reset_index(drop=True)

# %%
tdata
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 4023     41537    FL      F      742  396  470.0     0  15356      7     37
# 4024      4881    FL      M      599  100  423.0     4  11670     10     27
# 4025     66358    ND      M      593  258  299.0     0  10186      1     70
# 4026      2231    WI   male      564  217  397.0     0  12315      0     96
# 4027     68534    MI      M      651  431  505.0     0  14845      7     77
#
# ...

# %%
dcol = []
for item in tdata.columns:
    dcol.append(item.lower())

# %%
dcol
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic4',
#  'hvp1',
#  'ic5',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic3',
#  'avggift',
#  'tcode',
#  'dob',
#  'domain',
#  'target_d']

# %%
tdata.columns = dcol

# %%
tdata
# Out:
#       controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 4023     41537    FL      F      742  396  470.0     0  15356      7     37
# 4024      4881    FL      M      599  100  423.0     4  11670     10     27
# 4025     66358    ND      M      593  258  299.0     0  10186      1     70
# 4026      2231    WI   male      564  217  397.0     0  12315      0     96
# 4027     68534    MI      M      651  431  505.0     0  14845      7     77
#
# ...

# %%
tdata.columns==tfile.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
tfile
# Out:
#       controln      state gender   hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  \
# 0       119966         TX      F   321  225  281     0   9372      3     68
# 1       152470         CA      F  5725  610  807    97  53158     13     22
# 2        48527         AL   Male   931  407  496     0  17743      0     65
# 3       171528         CA      F  1895  317  471    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370     2  12416      0     75
# ...        ...        ...    ...   ...  ...  ...   ...    ...    ...    ...
# 2001     41537         FL      F   742  396  470     0  15356      7     37
# 2002      4881         FL      M   599  100  423     4  11670     10     27
# 2003     66358         ND      M   593  258  299     0  10186      1     70
# 2004      2231         WI   male   564  217  397     0  12315      0     96
# 2005     68534         MI      M   651  431  505     0  14845      7     77
#
#       ic2  ic3    avggift  tcode   dob domain  target_d
# ...

# %%
alldata = pd.concat([tfile,tdata],axis=0)

# %%
alldata
# Out:
#       controln      state gender   hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0       119966         TX      F   321  225  281.0     0   9372      3     68
# 1       152470         CA      F  5725  610  807.0    97  53158     13     22
# 2        48527         AL   Male   931  407  496.0     0  17743      0     65
# 3       171528         CA      F  1895  317  471.0    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370.0     2  12416      0     75
# ...        ...        ...    ...   ...  ...    ...   ...    ...    ...    ...
# 4023     41537         FL      F   742  396  470.0     0  15356      7     37
# 4024      4881         FL      M   599  100  423.0     4  11670     10     27
# 4025     66358         ND      M   593  258  299.0     0  10186      1     70
# 4026      2231         WI   male   564  217  397.0     0  12315      0     96
# 4027     68534         MI      M   651  431  505.0     0  14845      7     77
#
# ...

# %%
alldata = alldata.reset_index(drop=True)

# %%
alldata
# Out:
#       controln      state gender   hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0       119966         TX      F   321  225  281.0     0   9372      3     68
# 1       152470         CA      F  5725  610  807.0    97  53158     13     22
# 2        48527         AL   Male   931  407  496.0     0  17743      0     65
# 3       171528         CA      F  1895  317  471.0    46  17431     10     62
# 4        50122  Tennessee      F   715  318  370.0     2  12416      0     75
# ...        ...        ...    ...   ...  ...    ...   ...    ...    ...    ...
# 6029     41537         FL      F   742  396  470.0     0  15356      7     37
# 6030      4881         FL      M   599  100  423.0     4  11670     10     27
# 6031     66358         ND      M   593  258  299.0     0  10186      1     70
# 6032      2231         WI   male   564  217  397.0     0  12315      0     96
# 6033     68534         MI      M   651  431  505.0     0  14845      7     77
#
# ...

# %%
alldata.shape
# Out:
# (6034, 17)

# %%
alldata = alldata.drop(['dob','domain'],axis=1)

# %%
alldata
# Out:
#       controln      state gender   hv1  ic1    ic2  ic3    ic4    ic5  hvp1  \
# 0       119966         TX      F   321  225  264.0  243  281.0   9372     0
# 1       152470         CA      F  5725  610  763.0  698  807.0  53158    97
# 2        48527         AL   Male   931  407  502.0  439  496.0  17743     0
# 3       171528         CA      F  1895  317  389.0  405  471.0  17431    46
# 4        50122  Tennessee      F   715  318  340.0  352  370.0  12416     2
# ...        ...        ...    ...   ...  ...    ...  ...    ...    ...   ...
# 6029     41537         FL      F   742  396  424.0  450  470.0  15356     0
# 6030      4881         FL      M   599  100  406.0  200  423.0  11670     4
# 6031     66358         ND      M   593  258  298.0  274  299.0  10186     0
# 6032      2231         WI   male   564  217  386.0  295  397.0  12315     0
# 6033     68534         MI      M   651  431  451.0  455  505.0  14845     0
#
#       pobc1  pobc2    avggift  tcode  target_d
# ...

# %%
allcol = alldata.columns.tolist()

# %%
allcol
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic2',
#  'ic3',
#  'ic4',
#  'ic5',
#  'hvp1',
#  'pobc1',
#  'pobc2',
#  'avggift',
#  'tcode',
#  'target_d']

# %%
allcol[3]
# Out:
# 'hv1'

# %%
allcol =allcol[:6]+allcol[7:8]+allcol[6:7]+allcol[8:]

# %%
allcol
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'ic2',
#  'ic4',
#  'ic3',
#  'ic5',
#  'hvp1',
#  'pobc1',
#  'pobc2',
#  'avggift',
#  'tcode',
#  'target_d']

# %%
allcol = allcol[:5]+allcol[10:12]+allcol[5:10]+allcol[12:]

# %%
allcol
# Out:
# ['controln',
#  'state',
#  'gender',
#  'hv1',
#  'ic1',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic4',
#  'ic3',
#  'ic5',
#  'hvp1',
#  'avggift',
#  'tcode',
#  'target_d']

# %%
alldata= alldata[allcol]

# %%
alldata
# Out:
#       controln      state gender   hv1  ic1  pobc1  pobc2    ic2    ic4  ic3  \
# 0       119966         TX      F   321  225      3     68  264.0  281.0  243
# 1       152470         CA      F  5725  610     13     22  763.0  807.0  698
# 2        48527         AL   Male   931  407      0     65  502.0  496.0  439
# 3       171528         CA      F  1895  317     10     62  389.0  471.0  405
# 4        50122  Tennessee      F   715  318      0     75  340.0  370.0  352
# ...        ...        ...    ...   ...  ...    ...    ...    ...    ...  ...
# 6029     41537         FL      F   742  396      7     37  424.0  470.0  450
# 6030      4881         FL      M   599  100     10     27  406.0  423.0  200
# 6031     66358         ND      M   593  258      1     70  298.0  299.0  274
# 6032      2231         WI   male   564  217      0     96  386.0  397.0  295
# 6033     68534         MI      M   651  431      7     77  451.0  505.0  455
#
# ...

# %%
alldata = alldata.rename(columns={ 'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})

# %%
alldata
# Out:
#           id      state gender median_home_val  median_household_income  \
# 0     119966         TX      F             321                      225
# 1     152470         CA      F            5725                      610
# 2      48527         AL   Male             931                      407
# 3     171528         CA      F            1895                      317
# 4      50122  Tennessee      F             715                      318
# ...      ...        ...    ...             ...                      ...
# 6029   41537         FL      F             742                      396
# 6030    4881         FL      M             599                      100
# 6031   66358         ND      M             593                      258
# 6032    2231         WI   male             564                      217
# 6033   68534         MI      M             651                      431
#
#       pobc1  pobc2    ic2    ic4  ic3    ic5  hvp1    avggift  tcode  target_d
# ...

# %%
allcol = alldata.columns.tolist()

# %%
allcol
# Out:
# ['id',
#  'state',
#  'gender',
#  'median_home_val',
#  'median_household_income',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic4',
#  'ic3',
#  'ic5',
#  'hvp1',
#  'avggift',
#  'tcode',
#  'target_d']

# %%
allcol = allcol[:3]+allcol[5:9]+allcol[3:5]+allcol[9:]

# %%
allcol
# Out:
# ['id',
#  'state',
#  'gender',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic4',
#  'median_home_val',
#  'median_household_income',
#  'ic3',
#  'ic5',
#  'hvp1',
#  'avggift',
#  'tcode',
#  'target_d']

# %%
allcol = allcol[:7]+allcol[9:11]+allcol[7:9]+allcol[11:]

# %%
allcol
# Out:
# ['id',
#  'state',
#  'gender',
#  'pobc1',
#  'pobc2',
#  'ic2',
#  'ic4',
#  'ic3',
#  'ic5',
#  'median_home_val',
#  'median_household_income',
#  'hvp1',
#  'avggift',
#  'tcode',
#  'target_d']

# %%
alldata= alldata[allcol]

# %%
alldata
# Out:
#           id      state gender  pobc1  pobc2    ic2    ic4  ic3    ic5  \
# 0     119966         TX      F      3     68  264.0  281.0  243   9372
# 1     152470         CA      F     13     22  763.0  807.0  698  53158
# 2      48527         AL   Male      0     65  502.0  496.0  439  17743
# 3     171528         CA      F     10     62  389.0  471.0  405  17431
# 4      50122  Tennessee      F      0     75  340.0  370.0  352  12416
# ...      ...        ...    ...    ...    ...    ...    ...  ...    ...
# 6029   41537         FL      F      7     37  424.0  470.0  450  15356
# 6030    4881         FL      M     10     27  406.0  423.0  200  11670
# 6031   66358         ND      M      1     70  298.0  299.0  274  10186
# 6032    2231         WI   male      0     96  386.0  397.0  295  12315
# 6033   68534         MI      M      7     77  451.0  505.0  455  14845
#
#      median_home_val  median_household_income  hvp1    avggift  tcode  \
# ...

# %%
alldata['gender'].value_counts()
# Out:
# F          2950
# M          2187
# male        196
# female      166
# Female      130
# U           102
# Male         51
# J            33
# feamale      15
# A             2
# Name: gender, dtype: int64

# %%
alldata[(alldata['gender']=='M') | (alldata['gender']=='male') | (alldata['gender']=='Male')]
# Out:
#           id state gender  pobc1  pobc2    ic2    ic4  ic3    ic5  \
# 2      48527    AL   Male      0     65  502.0  496.0  439  17743
# 8     101676    MO      M      4     60  560.0  612.0  571  18860
# 10    141500    NV      M      9     19  357.0  381.0  358  12646
# 11     21599    SC      M      1     68  430.0  460.0  403  18128
# 13    139512    NM      M      4     39  368.0  416.0  366  14887
# ...      ...   ...    ...    ...    ...    ...    ...  ...    ...
# 6028   74303    MI      M      1     86  264.0  299.0  269  10088
# 6030    4881    FL      M     10     27  406.0  423.0  200  11670
# 6031   66358    ND      M      1     70  298.0  299.0  274  10186
# 6032    2231    WI   male      0     96  386.0  397.0  295  12315
# 6033   68534    MI      M      7     77  451.0  505.0  455  14845
#
#      median_home_val  median_household_income  hvp1    avggift  tcode  \
# 2                931                      407     0   4.416667      2
# ...

# %%
alldata[((alldata['gender']=='F') | (alldata['gender']=='female') | (alldata['gender']=='Female')  | (alldata['gender']=='feamale')) &(alldata['target_d']<100)]
# Out:
#           id      state gender  pobc1  pobc2    ic2    ic4  ic3    ic5  \
# 0     119966         TX      F      3     68  264.0  281.0  243   9372
# 1     152470         CA      F     13     22  763.0  807.0  698  53158
# 3     171528         CA      F     10     62  389.0  471.0  405  17431
# 4      50122  Tennessee      F      0     75  340.0  370.0  352  12416
# 5      92293         IL      F     16     74  897.0  973.0  934  35266
# ...      ...        ...    ...    ...    ...    ...    ...  ...    ...
# 6019   77441         WI      F      1     86  354.0  376.0  335  11623
# 6021  117326         TX      F      3     54  750.0  837.0  626  31480
# 6024   66762         MI      F      1     71  336.0  388.0  339  12653
# 6026  151175         CA      F     24     54  504.0  537.0  538  16165
# 6029   41537         FL      F      7     37  424.0  470.0  450  15356
#
#      median_home_val  median_household_income  hvp1    avggift  tcode  \
# ...

# %%
filtered2 =alldata[(alldata['gender']=='F') | (alldata['gender']=='female') | (alldata['gender']=='Female')  | (alldata['gender']=='feamale')]

# %%
filtered2.head(10)
# Out:
#         id      state gender  pobc1  pobc2    ic2    ic4  ic3    ic5  \
# 0   119966         TX      F      3     68  264.0  281.0  243   9372
# 1   152470         CA      F     13     22  763.0  807.0  698  53158
# 3   171528         CA      F     10     62  389.0  471.0  405  17431
# 4    50122  Tennessee      F      0     75  340.0  370.0  352  12416
# 5    92293         IL      F     16     74  897.0  973.0  934  35266
# 6    47191         AL      F      6     55  295.0  378.0  330  20090
# 7    89288         IL      F     18     70  467.0  507.0  464  15884
# 9    30051         GA      F      0     90  260.0  292.0  250   9279
# 12  110789         LA      F      0     91  204.0  277.0  226   9585
# 14  142662         CA      F     10     34  218.0  243.0  194  10014
#
#    median_home_val  median_household_income  hvp1    avggift  tcode  target_d
# 0              321                      225     0   8.058824      0      11.0
# ...

# %%
filtered2= filtered2.reset_index()

# %%
filtered2
# Out:
#       index      id      state gender  pobc1  pobc2    ic2    ic4  ic3    ic5  \
# 0         0  119966         TX      F      3     68  264.0  281.0  243   9372
# 1         1  152470         CA      F     13     22  763.0  807.0  698  53158
# 2         3  171528         CA      F     10     62  389.0  471.0  405  17431
# 3         4   50122  Tennessee      F      0     75  340.0  370.0  352  12416
# 4         5   92293         IL      F     16     74  897.0  973.0  934  35266
# ...     ...     ...        ...    ...    ...    ...    ...    ...  ...    ...
# 3256   6019   77441         WI      F      1     86  354.0  376.0  335  11623
# 3257   6021  117326         TX      F      3     54  750.0  837.0  626  31480
# 3258   6024   66762         MI      F      1     71  336.0  388.0  339  12653
# 3259   6026  151175         CA      F     24     54  504.0  537.0  538  16165
# 3260   6029   41537         FL      F      7     37  424.0  470.0  450  15356
#
# ...

# %%
filtered2[100:201]
# Out:
#      index      id state  gender  pobc1  pobc2    ic2    ic4  ic3    ic5  \
# 100    182  165641    CA       F     14     62  425.0  487.0  407  17677
# 101    186  158615    CA       F     14     34  374.0  442.0  347  24936
# 102    187  153353    CA       F     35     47  171.0  220.0  263   6142
# 103    188   42686    FL       F      8     13  289.0  352.0  313  13532
# 104    190  116608    TX       F      1     76  249.0  301.0  276  10637
# ..     ...     ...   ...     ...    ...    ...    ...    ...  ...    ...
# 196    366  190619    MI       F      1     85  502.0  515.0  453  16625
# 197    367   13727    NE       F      5     39  288.0  308.0  317  18892
# 198    369  190410    NC  female      3     53  354.0  435.0  384  16741
# 199    370  166711    CA       F     11     43  520.0  589.0  438  23719
# 200    371   78669    WI       F      6     82  389.0  383.0  223  12596
#
#     median_home_val  median_household_income  hvp1    avggift  tcode  target_d
# ...

# %%
filtered2.iloc[:100,2:6]
# Out:
#         state gender  pobc1  pobc2
# 0          TX      F      3     68
# 1          CA      F     13     22
# 2          CA      F     10     62
# 3   Tennessee      F      0     75
# 4          IL      F     16     74
# ..        ...    ...    ...    ...
# 95         UT      F      2     81
# 96         IN      F      1     82
# 97         MO      F      2     57
# 98         CA      F     16     44
# 99         FL      F      2     35
#
# [100 rows x 4 columns]

# %%
alldata.dtypes
# Out:
# id                           int64
# state                       object
# gender                      object
# pobc1                        int64
# pobc2                        int64
# ic2                        float64
# ic4                        float64
# ic3                          int64
# ic5                         object
# median_home_val             object
# median_household_income      int64
# hvp1                         int64
# avggift                    float64
# tcode                        int64
# target_d                   float64
# dtype: object

# %%
alldata.select_dtypes('int64','float64')
# Out:
#           id  pobc1  pobc2  ic3  median_household_income  hvp1  tcode
# 0     119966      3     68  243                      225     0      0
# 1     152470     13     22  698                      610    97      0
# 2      48527      0     65  439                      407     0      2
# 3     171528     10     62  405                      317    46      0
# 4      50122      0     75  352                      318     2      2
# ...      ...    ...    ...  ...                      ...   ...    ...
# 6029   41537      7     37  450                      396     0      2
# 6030    4881     10     27  200                      100     4     28
# 6031   66358      1     70  274                      258     0      1
# 6032    2231      0     96  295                      217     0      1
# 6033   68534      7     77  455                      431     0      1
#
# [6034 rows x 7 columns]

# %%
alldata['median_home_val'] =  pd.to_numeric(alldata['median_home_val'], errors='coerce')
alldata['ic5'] =  pd.to_numeric(alldata['ic5'], errors='coerce')
alldata.dtypes
# Out:
# id                           int64
# state                       object
# gender                      object
# pobc1                        int64
# pobc2                        int64
# ic2                        float64
# ic4                        float64
# ic3                          int64
# ic5                        float64
# median_home_val            float64
# median_household_income      int64
# hvp1                         int64
# avggift                    float64
# tcode                        int64
# target_d                   float64
# dtype: object

# %%
alldata2 = alldata.drop_duplicates()

# %%
alldata2.shape
# Out:
# (4001, 15)

# %%
alldata.shape
# Out:
# (6034, 15)
